# %%
#hello world

print('fjjd') 

print ('This is working')

print ('Marko \t fjsfd') 

print ('Marko \n djs \n \t second')

2+2
# Out:
# fjjd
# This is working
# Marko 	 fjsfd
# Marko
#  djs
#  	 second
# 0.8

# %% [markdown]
# # Title

# %%
! pwd 
print('This is for bash')
# Out:
# /usr/people/BZEDVZ/18perkov/test/prj1/res1
# This is for bash

# %%
ls
# Out:
# Coffee.py  First_Notebook.ipynb

# %%
! ls
# Out:
# Coffee.py  First_Notebook.ipynb

# %%
pwd
# Out:
# '/usr/people/BZEDVZ/18perkov/test/prj1/res1'

# %%
import numpy as np

# %%
y = 1+2

# %%
y
# Out:
# 3

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# Careful when changing kernels, everything I imorted or defined beforehand is gone

# %%
np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from '/usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/numpy/__init__.py'>

# %%
cd /usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/numpy/
# Out:
# /usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/numpy
# /usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
! cd /usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/numpy/

# %%
pwd
# Out:
# '/usr/people/BZEDVZ/18perkov/miniconda3/envs/test_env/lib/python3.10/site-packages/numpy'

# %%
pwd
# Out:
# '/usr/people/BZEDVZ/18perkov/test/prj1/res1'

# %%
pwd
# Out:
# '/usr/people/BZEDVZ/18perkov/test/prj1/res1'
